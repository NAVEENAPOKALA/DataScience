# %%
import numpy as np

# %%
data = np.random.randint(1,101,size=(4,4))
print(data)
# Out:
# [[83  5 63 46]
#  [60 27  7 59]
#  [84 70 55 16]
#  [13 88 65  2]]

# %%
print(data.sum())
# Out:
# 743

# %%
print(data.min())
# Out:
# 2

# %%
print(data.max())
# Out:
# 88

# %%
data[data%2==0]=0

# %%
print(data)
# Out:
# [[83  5 63  0]
#  [ 0 27  7 59]
#  [ 0  0 55  0]
#  [13  0 65  0]]

# %%
np.sum(data,axis=1)
# Out:
# array([151,  93,  55,  78])

# %%
data.transpose()
# Out:
# array([[83,  0,  0, 13],
#        [ 5, 27,  0,  0],
#        [63,  7, 55, 65],
#        [ 0, 59,  0,  0]])
