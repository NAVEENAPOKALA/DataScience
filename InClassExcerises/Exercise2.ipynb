# %%
import importlib
import pets
from pets import Pet
importlib.reload(pets)
# Out:
# <module 'pets' from '/Users/naveenapokala/Documents/Naveena/UNCG/Fall2025/DataScience/InClassExercise/pets.py'>

# %%
from pets import Pet

fluffy = Pet("Fluffy","Cat","2")

fluffy.display()
# Out:
# Fluffy is a Cat and is 2 years old
